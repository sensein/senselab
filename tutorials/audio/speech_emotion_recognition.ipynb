# %% [markdown]
# # Speech Emotion Recognition & Text Sentiment Analysis
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sensein/senselab/blob/main/tutorials/audio/speech_emotion_recognition.ipynb)
#
# Learn to classify emotions from speech using multiple models, understand what
# the scores mean, and complement acoustic emotion with text-based sentiment
# analysis.

# %%
# Install senselab and dependencies
# !pip install -q uv
# !uv pip install --pre --system "senselab"

# %% [markdown]
# > **⚠️ Restart runtime after install**
# >
# > The install may upgrade packages (e.g., numpy) that are already loaded.
# > Go to **Runtime → Restart session**, then **run all cells below** (skip this install cell).

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import torch
from pathlib import Path

from senselab.audio.data_structures import Audio
from senselab.audio.tasks.classification.speech_emotion_recognition.api import classify_emotions_from_speech
from senselab.audio.tasks.plotting.plotting import play_audio, plot_waveform
from senselab.audio.tasks.preprocessing.preprocessing import downmix_audios_to_mono, resample_audios
from senselab.audio.tasks.speech_to_text.api import transcribe_audios
from senselab.utils.data_structures import DeviceType, HFModel, SpeechBrainModel

device = DeviceType.CUDA if torch.cuda.is_available() else DeviceType.CPU
print(f"Using device: {device.value}")

# %% [markdown]
# ## 1. Record or Load Audio

# %%
# Record audio in Google Colab (uses browser microphone)
# If not in Colab, skip this cell and run the next one to load a sample file.
Path("tutorial_audio_files").mkdir(exist_ok=True)

try:
    from google.colab import output
    from IPython.display import HTML, display

    RECORD_JS = """
    <button id="record-btn" style="font-size:16px;padding:8px 16px">🎙 Click to Record (5s)</button>
    <script>
    (async () => {
        const btn = document.getElementById('record-btn');
        btn.onclick = async () => {
            btn.textContent = '🔴 Recording...';
            const stream = await navigator.mediaDevices.getUserMedia({audio: true});
            const recorder = new MediaRecorder(stream);
            const chunks = [];
            recorder.ondataavailable = e => chunks.push(e.data);
            recorder.onstop = async () => {
                stream.getTracks().forEach(t => t.stop());
                const blob = new Blob(chunks, {type: 'audio/wav'});
                const reader = new FileReader();
                reader.onload = () => {
                    const b64 = reader.result.split(',')[1];
                    google.colab.kernel.invokeFunction('save_recording', [b64], {});
                };
                reader.readAsDataURL(blob);
                btn.textContent = '✅ Recorded! Run the next cell to load it.';
            };
            recorder.start();
            setTimeout(() => recorder.stop(), 5000);
        };
    })();
    </script>
    """

    def save_recording(b64_data):
        import base64

        raw = base64.b64decode(b64_data)
        with open("tutorial_audio_files/my_recording.wav", "wb") as f:
            f.write(raw)

    output.register_callback("save_recording", save_recording)
    display(HTML(RECORD_JS))
    print("Click the button above to record 5 seconds of audio.")
    print("After recording, run the NEXT cell to load it.")
except Exception:
    print("Recording not available (not in Colab). Run the next cell to load a sample file.")

# %%
import urllib.request

base_url = "https://github.com/sensein/senselab/raw/main/src/tests/data_for_testing"

# Always download sample file
Path("tutorial_audio_files").mkdir(exist_ok=True)
sample_dest = Path("tutorial_audio_files/audio_48khz_mono_16bits.wav")
if not sample_dest.exists():
    urllib.request.urlretrieve(f"{base_url}/audio_48khz_mono_16bits.wav", str(sample_dest))

# Check if a recording was made
rec_path = Path("tutorial_audio_files/my_recording.wav")
if rec_path.exists() and rec_path.stat().st_size > 1000:
    audio_path = str(rec_path.resolve())
    print(f"Using your recording: {audio_path}")
else:
    audio_path = str(sample_dest.resolve())
    print(f"Using sample audio: {audio_path}")

audio = Audio(filepath=audio_path)
print(f"Loaded: {audio.waveform.shape[1]} samples at {audio.sampling_rate} Hz")
print(f"Duration: {audio.waveform.shape[1] / audio.sampling_rate:.2f} seconds")

# Ensure mono, resample to 16 kHz (expected by all SER models below)
audio_mono = downmix_audios_to_mono([audio])[0]
audio_16k = resample_audios([audio_mono], resample_rate=16000)[0]
print(f"Resampled to {audio_16k.sampling_rate} Hz, mono")

# %%
play_audio(audio_16k)

# %% [markdown]
# ## 2. Speech Emotion Recognition: Multiple Models
#
# Different SER models are trained on different data and produce different results.
# We compare three approaches:
#
# 1. **Discrete emotions from conversational speech** (IEMOCAP-trained)
# 2. **Discrete emotions from acted speech** (RAVDESS-trained)
# 3. **Dimensional emotions** (valence / arousal / dominance)

# %%
# Model 1: Trained on conversational speech (IEMOCAP)
model_iemocap = HFModel(path_or_uri="superb/wav2vec2-base-superb-er")

# Model 2: Trained on acted speech (RAVDESS)
model_ravdess = HFModel(path_or_uri="ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition")

# Model 3: SpeechBrain IEMOCAP (wav2vec2, 4-class)
model_sb = SpeechBrainModel(path_or_uri="speechbrain/emotion-recognition-wav2vec2-IEMOCAP")

# Model 4: Continuous/dimensional emotions
model_continuous = HFModel(path_or_uri="audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim")


print("Running Model 1 (IEMOCAP - conversational)...")
result_iemocap = classify_emotions_from_speech([audio_16k], model=model_iemocap, device=device)

print("Running Model 2 (RAVDESS - acted)...")
result_ravdess = classify_emotions_from_speech([audio_16k], model=model_ravdess, device=device)

print("Running Model 3 (SpeechBrain IEMOCAP)...")
result_sb = classify_emotions_from_speech([audio_16k], model=model_sb, device=device)

print("Running Model 4 (MSP-Podcast - continuous)...")
try:
    result_continuous = classify_emotions_from_speech([audio_16k], model=model_continuous, device=device)
except Exception as e:
    print(f"  Continuous model failed (subprocess venv issue): {e}")
    result_continuous = None

print("Done!")

# %% [markdown]
# ### Model Comparison

# %%
# Build list of (title, result) pairs for models that succeeded
model_results = [
    ("IEMOCAP (conversational)", result_iemocap[0]),
    ("RAVDESS (acted)", result_ravdess[0]),
]
if result_continuous is not None:
    model_results.append(("MSP-Podcast (continuous)", result_continuous[0]))

n_models = len(model_results)
colors = ["#4C72B0", "#DD8452", "#55A868"]

fig, axes = plt.subplots(1, n_models, figsize=(6 * n_models, 5))
if n_models == 1:
    axes = [axes]

for idx, (title, result) in enumerate(model_results):
    ax = axes[idx]
    labels = result.labels
    scores = result.scores
    y_pos = range(len(labels))
    ax.barh(y_pos, scores, color=colors[idx], edgecolor="white")
    ax.set_yticks(y_pos)
    ax.set_yticklabels(labels)
    ax.set_xlabel("Score")
    ax.set_title(title)
    ax.set_xlim(0, max(scores) * 1.15 if max(scores) > 0 else 1)
    ax.invert_yaxis()
    # Annotate bars
    for i, s in enumerate(scores):
        ax.text(s + 0.005, i, f"{s:.3f}", va="center", fontsize=9)

plt.suptitle("Speech Emotion Recognition: Model Comparison", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# Comparison table
print("\n=== Comparison Table ===")
for title, result in model_results:
    top_label, top_score = result.top()
    second_score = result.scores[1] if len(result.scores) > 1 else 0.0
    margin = top_score - second_score
    print(f"  {title:35s} | Top: {top_label:12s} ({top_score:.3f}) | Margin: {margin:.3f}")

# %% [markdown]
# ## 3. Understanding Emotion Scores
#
# **Near-uniform distributions**: When all scores are roughly equal (e.g., ~0.12
# for 8 classes), the model is not discriminating well. This happens when:
# - The model was trained on acted speech but tested on natural speech
# - The audio is too short or noisy
# - The emotion is not strong enough for the model's threshold
#
# **Relative vs absolute**: Look at the *ordering* (which emotion ranks highest)
# and the *margin* (how much higher than the second), not the absolute scores.
#
# **Acted vs natural speech**: RAVDESS models expect dramatic, exaggerated
# expression. IEMOCAP models handle subtler conversational emotions better.
#
# **Dimensional models**: Valence (positive ↔ negative), arousal (calm ↔ excited),
# dominance (submissive ↔ powerful) give a continuous view that can be more
# informative than categorical labels.

# %%
# Load a RAVDESS sample (clearly acted emotion) to show what "good" discrimination looks like
from datasets import load_dataset

ravdess = load_dataset("xbgoose/ravdess", split="train[:5]")

# Pick the first sample and convert to senselab Audio
sample = ravdess[0]
audio_decoder = sample["audio"]
# Extract raw audio data from the HF AudioDecoder
all_samples = audio_decoder.get_all_samples()
waveform_data = all_samples.data.float()
sr = all_samples.sample_rate

acted_audio = Audio(waveform=waveform_data, sampling_rate=sr)
acted_16k = resample_audios([acted_audio], resample_rate=16000)[0]
acted_16k = downmix_audios_to_mono([acted_16k])[0]

print(f"RAVDESS sample emotion label: {sample['emotion']}")
print(f"Audio: {acted_16k.waveform.shape[1]} samples at {acted_16k.sampling_rate} Hz")

# Run RAVDESS model on acted speech
result_acted = classify_emotions_from_speech([acted_16k], model=model_ravdess, device=device)

# Compare score distributions
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Natural speech
ax = axes[0]
labels_nat = result_ravdess[0].labels
scores_nat = result_ravdess[0].scores
ax.barh(range(len(labels_nat)), scores_nat, color="#DD8452")
ax.set_yticks(range(len(labels_nat)))
ax.set_yticklabels(labels_nat)
ax.set_xlabel("Score")
ax.set_title("RAVDESS model on natural speech")
ax.invert_yaxis()

# Acted speech
ax = axes[1]
labels_act = result_acted[0].labels
scores_act = result_acted[0].scores
ax.barh(range(len(labels_act)), scores_act, color="#55A868")
ax.set_yticks(range(len(labels_act)))
ax.set_yticklabels(labels_act)
ax.set_xlabel("Score")
ax.set_title(f"RAVDESS model on acted speech (label: {sample['emotion']})")
ax.invert_yaxis()

plt.suptitle("Score Distribution: Natural vs Acted Speech", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# Print score spread
spread_nat = max(scores_nat) - min(scores_nat)
spread_act = max(scores_act) - min(scores_act)
print(f"\nScore spread (natural speech):  {spread_nat:.3f} (low spread = poor discrimination)")
print(f"Score spread (acted speech):    {spread_act:.3f} (high spread = good discrimination)")

# %% [markdown]
# ## 4. Text Sentiment from Transcription
#
# Emotion from *how* you speak (paralinguistic) is different from sentiment of
# *what* you say (linguistic). Someone saying "I'm fine" in a sad voice: text =
# neutral, acoustic = sad. Together they give a richer picture.

# %%
# Transcribe
transcripts = transcribe_audios([audio_16k], model=HFModel(path_or_uri="openai/whisper-large-v3-turbo"))
text = transcripts[0].text
print(f"Transcription: {text}")

# Text sentiment
from transformers import pipeline

sentiment_pipe = pipeline(
    "text-classification",
    model="cardiffnlp/twitter-roberta-base-sentiment-latest",
    device=device.value if device == DeviceType.CUDA else -1,
)
sentiment = sentiment_pipe(text)
print(f"\nText Sentiment: {sentiment[0]['label']} (confidence: {sentiment[0]['score']:.3f})")

# %% [markdown]
# ### Comparing Acoustic Emotion and Text Sentiment

# %%
# Side-by-side comparison
print("=" * 65)
print(f"{'Approach':<30s} | {'Result':<15s} | {'Score':>8s}")
print("-" * 65)

# Acoustic SER results
top_iemocap, score_iemocap = result_iemocap[0].top()
print(f"{'SER (IEMOCAP)':<30s} | {top_iemocap:<15s} | {score_iemocap:>8.3f}")

top_ravdess, score_ravdess = result_ravdess[0].top()
print(f"{'SER (RAVDESS)':<30s} | {top_ravdess:<15s} | {score_ravdess:>8.3f}")

if result_continuous is not None:
    top_cont, score_cont = result_continuous[0].top()
    print(f"{'SER (Continuous)':<30s} | {top_cont:<15s} | {score_cont:>8.3f}")

# Text sentiment
print(f"{'Text Sentiment':<30s} | {sentiment[0]['label']:<15s} | {sentiment[0]['score']:>8.3f}")
print("=" * 65)
print(f'\nTranscription: "{text}"')

# %% [markdown]
# ## 5. Processing Your Audio Through Multiple Models
#
# Here is a complete example of how to load your own audio and run it
# through multiple SER models to get a comprehensive emotion profile.

# %%
# === Complete example: process your audio through multiple SER models ===

# Step 1: Load and preprocess your audio
my_audio = Audio(filepath=os.path.abspath("tutorial_audio_files/audio_48khz_mono_16bits.wav"))
my_audio_16k = resample_audios(downmix_audios_to_mono([my_audio]), resample_rate=16000)[0]

# Step 2: Define models to compare
models = {
    "IEMOCAP (HF)": HFModel(path_or_uri="superb/wav2vec2-base-superb-er"),
    "IEMOCAP (SpeechBrain)": SpeechBrainModel(path_or_uri="speechbrain/emotion-recognition-wav2vec2-IEMOCAP"),
    "RAVDESS": HFModel(path_or_uri="ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition"),
}

# Step 3: Run all models
print("=== Emotion Analysis Results ===")
print(f"Audio: {my_audio_16k.waveform.shape[1] / 16000:.1f}s at {my_audio_16k.sampling_rate}Hz\n")

for name, model in models.items():
    result = classify_emotions_from_speech([my_audio_16k], model=model, device=device)
    top = result[0].top_k(3)  # top 3 emotions
    print(f"{name}:")
    for label, score in top:
        bar = "\u2588" * int(score * 30)
        print(f"  {label:12s} {score:.3f} {bar}")
    print()

# %% [markdown]
# ## Summary
#
# | Approach | Input | Output | Best For |
# |----------|-------|--------|----------|
# | SER (IEMOCAP) | Audio | Discrete emotions | Conversational speech |
# | SER (RAVDESS) | Audio | Discrete emotions | Acted/dramatic speech |
# | SER (Continuous) | Audio | Valence/arousal/dominance | Dimensional analysis |
# | Text Sentiment | Transcribed text | Positive/negative/neutral | What was said |
