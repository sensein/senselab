# %% [markdown]
# # Speech enhancement
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sensein/senselab/blob/main/tutorials/audio/speech_enhancement.ipynb)
#
# This tutorial demonstrates how to use the `enhance_audios` function to enhance speech signals.
#
# We will show you how to use the [Speformer model (speechbrain/sepformer-wham16k-enhancement)](https://huggingface.co/speechbrain/sepformer-wham16k-enhancement).

# %%
# %pip install senselab
# Out:
# Requirement already satisfied: senselab[audio] in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (0.42.1)
# Requirement already satisfied: accelerate in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (1.10.1)
# Requirement already satisfied: audiomentations<1.0,>=0.42 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.43.1)
# Requirement already satisfied: coqui-tts<1.0,>=0.27 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.27.1)
# Requirement already satisfied: datasets<4.0,>=3.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.34.5)
# Requirement already satisfied: iso639<1.0,>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.1.4)
# Requirement already satisfied: jiwer<5.0,>=4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (4.0.0)
# Requirement already satisfied: matplotlib<4.0,>=3.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (3.10.6)
# Requirement already satisfied: nemo-toolkit<3.0,>=2.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.3.0)
# Requirement already satisfied: nest-asyncio<2.0,>=1.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (1.6.0)
# Requirement already satisfied: nltk<4.0,>=3.9 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (3.9.1)
# Requirement already satisfied: opensmile<3.0,>=2.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (2.6.0)
# Requirement already satisfied: praat-parselmouth<1.0,>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.4.6)
# Requirement already satisfied: pyannote-audio<4.0,>=3.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (3.4.0)
# Requirement already satisfied: pycountry<25.0,>=24.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (24.6.1)
# Requirement already satisfied: pydantic<3.0,>=2.11 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (2.11.9)
# Requirement already satisfied: pydra>=1.0a0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (1.0a3)
# Requirement already satisfied: python-ffmpeg<3.0,>=2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (2.0.12)
# Requirement already satisfied: scikit-learn<2.0,>=1.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (1.7.2)
# Requirement already satisfied: speechbrain<1.1,>=1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (1.0.3)
# Requirement already satisfied: torch<3.0,>=2.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (2.8.0)
# Requirement already satisfied: torch-audiomentations<1.0,>=0.12 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.12.0)
# Requirement already satisfied: torchaudio<3.0,>=2.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (2.8.0)
# Requirement already satisfied: torchvision<1.0,>=0.23 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.23.0)
# Requirement already satisfied: transformers<5.0,>=4.55 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (4.56.1)
# Requirement already satisfied: umap-learn<1.0,>=0.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.5.9.post2)
# Requirement already satisfied: vocos<1.0,>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio]) (0.1.0)
# Requirement already satisfied: numpy<3,>=1.22.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (1.26.4)
# Requirement already satisfied: numpy-minmax<1,>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (0.3.1)
# Requirement already satisfied: numpy-rms<1,>=0.4.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (0.4.2)
# Requirement already satisfied: librosa!=0.10.0,<0.12.0,>=0.8.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (0.11.0)
# Requirement already satisfied: python-stretch<1,>=0.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (0.3.1)
# Requirement already satisfied: scipy<2,>=1.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (1.16.2)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio]) (0.5.0.post1)
# Requirement already satisfied: anyascii>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.3.3)
# Requirement already satisfied: coqpit-config<0.3.0,>=0.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.2.1)
# Requirement already satisfied: coqui-tts-trainer<0.4.0,>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.3.1)
# Requirement already satisfied: cython>=3.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (3.1.3)
# Requirement already satisfied: einops>=0.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.8.1)
# Requirement already satisfied: encodec>=0.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.1.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2024.12.0)
# Requirement already satisfied: gruut>=2.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.4.0)
# Requirement already satisfied: inflect>=5.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (7.5.0)
# Requirement already satisfied: monotonic-alignment-search>=0.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.2.0)
# Requirement already satisfied: num2words>=0.5.14 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.5.14)
# Requirement already satisfied: packaging>=23.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (24.2)
# Requirement already satisfied: pysbd>=0.3.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.3.4)
# Requirement already satisfied: pyyaml>=6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (6.0.2)
# Requirement already satisfied: soundfile>=0.12.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (0.13.1)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio]) (4.15.0)
# Requirement already satisfied: psutil>=5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (7.0.0)
# Requirement already satisfied: tensorboard>=2.17.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.20.0)
# Requirement already satisfied: filelock in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (0.3.8)
# Requirement already satisfied: pandas in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (2.32.5)
# Requirement already satisfied: xxhash in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio]) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (3.12.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34->senselab[audio]) (1.1.10)
# Requirement already satisfied: click>=8.1.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jiwer<5.0,>=4.0->senselab[audio]) (8.2.1)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jiwer<5.0,>=4.0->senselab[audio]) (3.14.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (0.61.0)
# Requirement already satisfied: joblib>=1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (1.8.2)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio]) (2.9.0.post0)
# Requirement already satisfied: onnx>=1.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.17.0)
# Requirement already satisfied: protobuf==4.24.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (4.24.4)
# Requirement already satisfied: ruamel.yaml in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.18.15)
# Requirement already satisfied: setuptools>=70.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (80.9.0)
# Requirement already satisfied: text-unidecode in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.3)
# Requirement already satisfied: wget in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.2)
# Requirement already satisfied: wrapt in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.17.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (0.44.0)
# Requirement already satisfied: braceexpand in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.1.7)
# Requirement already satisfied: editdistance in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.8.1)
# Requirement already satisfied: g2p_en in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.1.0)
# Requirement already satisfied: kaldi-python-io in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.2.2)
# Requirement already satisfied: kaldiio in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.18.1)
# Requirement already satisfied: lhotse>=1.26.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.30.3)
# Requirement already satisfied: marshmallow in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (4.0.1)
# Requirement already satisfied: optuna in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (4.5.0)
# Requirement already satisfied: pyannote.core in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (5.0.0)
# Requirement already satisfied: pyannote.metrics in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.2.1)
# Requirement already satisfied: pydub in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.25.1)
# Requirement already satisfied: pyloudnorm in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.1.1)
# Requirement already satisfied: resampy in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.4.3)
# Requirement already satisfied: sox<=1.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.5.0)
# Requirement already satisfied: texterrors<1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.5.1)
# Requirement already satisfied: cloudpickle in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.1.1)
# Requirement already satisfied: fiddle in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.3.0)
# Requirement already satisfied: hydra-core<=1.3.2,>1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.3.2)
# Requirement already satisfied: lightning<=2.4.0,>2.2.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.4.0)
# Requirement already satisfied: omegaconf<=2.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.3.0)
# Requirement already satisfied: peft in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.17.1)
# Requirement already satisfied: torchmetrics>=0.11.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.8.2)
# Requirement already satisfied: wandb in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.21.4)
# Requirement already satisfied: webdataset>=0.2.86 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.0.2)
# Requirement already satisfied: mediapy==1.1.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.1.6)
# Requirement already satisfied: sacremoses>=0.0.43 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.1.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.2.1)
# Requirement already satisfied: ipython in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (9.5.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from hydra-core<=1.3.2,>1.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (4.9.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lightning<=2.4.0,>2.2.1->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.15.2)
# Requirement already satisfied: pytorch-lightning in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lightning<=2.4.0,>2.2.1->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.5.5)
# Requirement already satisfied: regex>=2021.8.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nltk<4.0,>=3.9->senselab[audio]) (2025.9.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from numpy-minmax<1,>=0.3.0->audiomentations<1.0,>=0.42->senselab[audio]) (2.0.0)
# Requirement already satisfied: audobject>=0.6.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from opensmile<3.0,>=2.6->senselab[audio]) (0.7.12)
# Requirement already satisfied: audinterface>=0.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from opensmile<3.0,>=2.6->senselab[audio]) (1.3.1)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (0.4.0)
# Requirement already satisfied: pyannote.database<6.0,>=5.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (5.1.3)
# Requirement already satisfied: pyannote.pipeline<4.0,>=3.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (3.0.1)
# Requirement already satisfied: pytorch_metric_learning>=2.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (2.9.0)
# Requirement already satisfied: rich>=12.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (14.1.0)
# Requirement already satisfied: semver>=3.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (3.0.4)
# Requirement already satisfied: tensorboardX>=2.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio]) (2.6.4)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.core->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.4.0)
# Requirement already satisfied: typer>=0.12.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.database<6.0,>=5.0.1->pyannote-audio<4.0,>=3.3->senselab[audio]) (0.17.4)
# Requirement already satisfied: docopt>=0.6.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.9.0)
# Requirement already satisfied: sympy>=1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.11->senselab[audio]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.11->senselab[audio]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.11->senselab[audio]) (0.4.1)
# Requirement already satisfied: pyee in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from python-ffmpeg<3.0,>=2.0->senselab[audio]) (13.0.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from scikit-learn<2.0,>=1.7->senselab[audio]) (3.6.0)
# Requirement already satisfied: hyperpyyaml in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from speechbrain<1.1,>=1->senselab[audio]) (1.2.2)
# Requirement already satisfied: pybind11 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.0.1)
# Requirement already satisfied: plac in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.4.5)
# Requirement already satisfied: loguru in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.7.3)
# Requirement already satisfied: termcolor in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.1.0)
# Requirement already satisfied: Levenshtein in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.27.1)
# Requirement already satisfied: networkx in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch<3.0,>=2.8->senselab[audio]) (3.5)
# Requirement already satisfied: jinja2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch<3.0,>=2.8->senselab[audio]) (3.1.6)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch-audiomentations<1.0,>=0.12->senselab[audio]) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch-audiomentations<1.0,>=0.12->senselab[audio]) (1.2.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from transformers<5.0,>=4.55->senselab[audio]) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from transformers<5.0,>=4.55->senselab[audio]) (0.6.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from umap-learn<1.0,>=0.5->senselab[audio]) (0.5.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (3.10)
# Requirement already satisfied: audeer>=2.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (2.2.2)
# Requirement already satisfied: audformat<2.0.0,>=1.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (1.3.2)
# Requirement already satisfied: audiofile>=1.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (1.5.1)
# Requirement already satisfied: audmath>=1.4.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (1.4.2)
# Requirement already satisfied: audresample<2.0.0,>=1.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (1.3.4)
# Requirement already satisfied: iso639-lang in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (2.6.3)
# Requirement already satisfied: iso3166 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (2.1.1)
# Requirement already satisfied: oyaml in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile<3.0,>=2.6->senselab[audio]) (1.0)
# Requirement already satisfied: asttokens>=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audobject>=0.6.1->opensmile<3.0,>=2.6->senselab[audio]) (3.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audobject>=0.6.1->opensmile<3.0,>=2.6->senselab[audio]) (8.7.0)
# Requirement already satisfied: pycparser in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from cffi>=1.0.0->numpy-minmax<1,>=0.3.0->audiomentations<1.0,>=0.42->senselab[audio]) (2.23)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.17.0)
# Requirement already satisfied: dateparser~=1.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (0.13.0)
# Requirement already satisfied: gruut_lang_en~=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.2.0)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (0.9.11)
# Requirement already satisfied: pytz in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2025.2)
# Requirement already satisfied: tzlocal in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (5.3.1)
# Requirement already satisfied: six in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jsonlines~=1.2.0->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.17.0)
# Requirement already satisfied: gruut_lang_de~=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.0.1)
# Requirement already satisfied: gruut_lang_es~=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.0.1)
# Requirement already satisfied: gruut_lang_fr~=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.0.2)
# Requirement already satisfied: zipp>=3.20 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile<3.0,>=2.6->senselab[audio]) (3.23.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from inflect>=5.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from inflect>=5.6.0->coqui-tts<1.0,>=0.27->senselab[audio]) (4.4.4)
# Requirement already satisfied: cytoolz>=0.10.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lhotse>=1.26.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.0.1)
# Requirement already satisfied: intervaltree>=3.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lhotse>=1.26.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.1.0)
# Requirement already satisfied: lilcom>=1.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lhotse>=1.26.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.8.1)
# Requirement already satisfied: toolz>=0.8.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from cytoolz>=0.10.1->lhotse>=1.26.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.0.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from optuna->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.16.5)
# Requirement already satisfied: colorlog in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from optuna->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from optuna->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.0.43)
# Requirement already satisfied: Mako in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from alembic>=1.5.0->optuna->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.3.10)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pandas->datasets<4.0,>=3.6->senselab[audio]) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio]) (4.4.0)
# Requirement already satisfied: etelemetry>=0.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydra>=1.0a0->senselab[audio]) (0.3.1)
# Requirement already satisfied: fileformats>=0.15.0a7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydra>=1.0a0->senselab[audio]) (0.15.7)
# Requirement already satisfied: ci-info>=0.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from etelemetry>=0.3.1->pydra>=1.0a0->senselab[audio]) (0.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.0,>=3.6->senselab[audio]) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.0,>=3.6->senselab[audio]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.0,>=3.6->senselab[audio]) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from rich>=12.0.0->pyannote-audio<4.0,>=3.3->senselab[audio]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from rich>=12.0.0->pyannote-audio<4.0,>=3.3->senselab[audio]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote-audio<4.0,>=3.3->senselab[audio]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from sympy>=1.1->pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (3.1.1)
# Requirement already satisfied: primePy>=1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations<1.0,>=0.12->senselab[audio]) (1.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from typer>=0.12.1->pyannote.database<6.0,>=5.0.1->pyannote-audio<4.0,>=3.3->senselab[audio]) (1.5.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio]) (3.0.2)
# Requirement already satisfied: graphviz in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fiddle->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.21)
# Requirement already satisfied: libcst in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fiddle->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.8.4)
# Requirement already satisfied: distance>=0.1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from g2p_en->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.1.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ruamel.yaml->nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.2.12)
# Requirement already satisfied: ipython-pygments-lexers in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.0.52)
# Requirement already satisfied: stack_data in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jedi>=0.16->ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pexpect>4.3->ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.7.0)
# Requirement already satisfied: future>=0.16.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyloudnorm->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (1.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from stack_data->ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from stack_data->ipython->mediapy==1.1.6->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (0.2.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (3.1.45)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio]) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the necessary modules from the Senselab package for audio processing
import os

from senselab.audio.data_structures import Audio
from senselab.audio.tasks.plotting.plotting import play_audio
from senselab.audio.tasks.preprocessing import resample_audios
from senselab.audio.tasks.speech_enhancement import enhance_audios
from senselab.utils.data_structures import DeviceType, SpeechBrainModel
# Out:
# /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages/speechbrain/utils/torch_audio_backend.py:57: UserWarning: torchaudio._backend.list_audio_backends has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   available_backends = torchaudio.list_audio_backends()

# %%
# !mkdir -p tutorial_audio_files
# !wget -O tutorial_audio_files/audio_48khz_mono_16bits.wav https://github.com/sensein/senselab/raw/main/src/tests/data_for_testing/audio_48khz_mono_16bits.wav

# Load an audio file from the specified file path
audio = Audio(filepath=os.path.abspath("tutorial_audio_files/audio_48khz_mono_16bits.wav"))

# Resample the audio to 16kHz to match the model's expected input format
audio = resample_audios([audio], 16000)[0]

# Play the resampled audio to verify the preprocessing step
play_audio(audio)
# Out:
# --2025-09-15 19:08:20--  https://github.com/sensein/senselab/raw/main/src/tests/data_for_testing/audio_48khz_mono_16bits.wav
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sensein/senselab/main/src/tests/data_for_testing/audio_48khz_mono_16bits.wav [following]
# --2025-09-15 19:08:20--  https://raw.githubusercontent.com/sensein/senselab/main/src/tests/data_for_testing/audio_48khz_mono_16bits.wav
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 472488 (461K) [audio/wav]
# Saving to: ‘tutorial_audio_files/audio_48khz_mono_16bits.wav’
#
# tutorial_audio_file 100%[===================>] 461.41K  --.-KB/s    in 0.08s
#
# 2025-09-15 19:08:20 (5.71 MB/s) - ‘tutorial_audio_files/audio_48khz_mono_16bits.wav’ saved [472488/472488]
# /Users/fabiocat/git/senselab/src/senselab/audio/data_structures/audio.py:132: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(self._file_path)
# /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /Users/fabiocat/git/senselab/src/senselab/audio/data_structures/audio.py:183: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(filepath)
# /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Load a pre-trained speech enhancement model from SpeechBrain (sepformer-wham16k-enhancement)
model = SpeechBrainModel(path_or_uri="speechbrain/sepformer-wham16k-enhancement", revision="main")

# Initialize the device for running the model
device = DeviceType.CPU

# %%
# Enhance the audio using the loaded model, running the process on the specified device
enhanced_audio = enhance_audios(audios=[audio], model=model, device=device)[0]
# Out:
# /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages/speechbrain/utils/torch_audio_backend.py:57: UserWarning: torchaudio._backend.list_audio_backends has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   available_backends = torchaudio.list_audio_backends()
# Failed to load SpeechBrain model as a SpectralMaskEnhancement model: Need hparams['compute_stft']
# Trying to load as a SepformerSeparation model...
# 2025-09-15 19:08:26,091 - senselab - INFO - Time taken to initialize the speechbrain model: 1.14 seconds
# 2025-09-15 19:08:30,041 - senselab - INFO - Time taken for enhancing the audios: 3.95 seconds

# %%
# Play the enhanced audio to hear the result after speech enhancement
play_audio(enhanced_audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
