# %% [markdown]
# # 🎛 Tutorial: Using senselab-ai
#
# senselab-ai lets you analyze your data by chatting in natural language.
# You can simply ask the agent what you want to do (e.g., load audio files, preprocess them, extract features, transcribe, etc.), and it will generate and run the corresponding senselab code while also showing you the code it used.
#
# This makes it perfect for exploration and for users who prefer not to code directly.

# %% [markdown]
# ## 1. Install
# Install senselab with the senselab-ai and audio extras:

# %%
pip install "senselab[senselab-ai]"
# Out:
# Requirement already satisfied: senselab[audio,senselab-ai] in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (0.42.1)
# Requirement already satisfied: accelerate in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (1.10.1)
# Requirement already satisfied: audiomentations<1.0,>=0.42 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.43.1)
# Requirement already satisfied: coqui-tts<1.0,>=0.27 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.27.1)
# Requirement already satisfied: datasets<4.0,>=3.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.34.5)
# Requirement already satisfied: ipykernel<7.0,>=6.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (6.30.1)
# Requirement already satisfied: ipywidgets<9.0,>=8.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (8.1.7)
# Requirement already satisfied: iso639<1.0,>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.1.4)
# Requirement already satisfied: jiwer<5.0,>=4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (4.0.0)
# Requirement already satisfied: matplotlib<4.0,>=3.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (3.10.6)
# Requirement already satisfied: nbformat<6.0,>=5.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (5.10.4)
# Requirement already satisfied: nbss-upload<1.0,>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.1)
# Requirement already satisfied: nemo-toolkit<3.0,>=2.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.3.0)
# Requirement already satisfied: nest-asyncio<2.0,>=1.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (1.6.0)
# Requirement already satisfied: nltk<4.0,>=3.9 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (3.9.1)
# Requirement already satisfied: notebook-intelligence<2.4.0,>=2.3.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (2.3.2)
# Requirement already satisfied: opensmile<3.0,>=2.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (2.6.0)
# Requirement already satisfied: praat-parselmouth<1.0,>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.4.6)
# Requirement already satisfied: pyannote-audio<4.0,>=3.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (3.4.0)
# Requirement already satisfied: pycountry<25.0,>=24.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (24.6.1)
# Requirement already satisfied: pydantic<3.0,>=2.11 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (2.11.9)
# Requirement already satisfied: pydra>=1.0a0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (1.0a3)
# Requirement already satisfied: python-ffmpeg<3.0,>=2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (2.0.12)
# Requirement already satisfied: scikit-learn<2.0,>=1.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (1.7.2)
# Requirement already satisfied: speechbrain<1.1,>=1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (1.0.3)
# Requirement already satisfied: torch<3.0,>=2.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (2.8.0)
# Requirement already satisfied: torch-audiomentations<1.0,>=0.12 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.12.0)
# Requirement already satisfied: torchaudio<3.0,>=2.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (2.8.0)
# Requirement already satisfied: torchvision<1.0,>=0.23 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.23.0)
# Requirement already satisfied: transformers<5.0,>=4.55 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (4.56.1)
# Requirement already satisfied: umap-learn<1.0,>=0.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.5.9.post2)
# Requirement already satisfied: vocos<1.0,>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from senselab[audio,senselab-ai]) (0.1.0)
# Requirement already satisfied: numpy<3,>=1.22.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (1.26.4)
# Requirement already satisfied: numpy-minmax<1,>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.3.1)
# Requirement already satisfied: numpy-rms<1,>=0.4.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.4.2)
# Requirement already satisfied: librosa!=0.10.0,<0.12.0,>=0.8.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.11.0)
# Requirement already satisfied: python-stretch<1,>=0.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.3.1)
# Requirement already satisfied: scipy<2,>=1.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (1.16.2)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.5.0.post1)
# Requirement already satisfied: anyascii>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.3.3)
# Requirement already satisfied: coqpit-config<0.3.0,>=0.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.2.1)
# Requirement already satisfied: coqui-tts-trainer<0.4.0,>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.3.1)
# Requirement already satisfied: cython>=3.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (3.1.3)
# Requirement already satisfied: einops>=0.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.8.1)
# Requirement already satisfied: encodec>=0.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.1.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (2024.12.0)
# Requirement already satisfied: gruut>=2.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (2.4.0)
# Requirement already satisfied: inflect>=5.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (7.5.0)
# Requirement already satisfied: monotonic-alignment-search>=0.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.2.0)
# Requirement already satisfied: num2words>=0.5.14 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.5.14)
# Requirement already satisfied: packaging>=23.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (24.2)
# Requirement already satisfied: pysbd>=0.3.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.3.4)
# Requirement already satisfied: pyyaml>=6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (6.0.2)
# Requirement already satisfied: soundfile>=0.12.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.13.1)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (4.15.0)
# Requirement already satisfied: psutil>=5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (7.0.0)
# Requirement already satisfied: tensorboard>=2.17.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (2.20.0)
# Requirement already satisfied: filelock in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (0.3.8)
# Requirement already satisfied: pandas in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (2.32.5)
# Requirement already satisfied: xxhash in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (3.12.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34->senselab[audio,senselab-ai]) (1.1.10)
# Requirement already satisfied: appnope>=0.1.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (0.1.7)
# Requirement already satisfied: pyzmq>=25 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipywidgets<9.0,>=8.1->senselab[audio,senselab-ai]) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ipywidgets<9.0,>=8.1->senselab[audio,senselab-ai]) (3.0.15)
# Requirement already satisfied: click>=8.1.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jiwer<5.0,>=4.0->senselab[audio,senselab-ai]) (8.2.1)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jiwer<5.0,>=4.0->senselab[audio,senselab-ai]) (3.14.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.61.0)
# Requirement already satisfied: joblib>=1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (1.8.2)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.10->senselab[audio,senselab-ai]) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nbformat<6.0,>=5.10->senselab[audio,senselab-ai]) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nbformat<6.0,>=5.10->senselab[audio,senselab-ai]) (4.25.1)
# Requirement already satisfied: onnx>=1.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.17.0)
# Requirement already satisfied: protobuf==4.24.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (4.24.4)
# Requirement already satisfied: ruamel.yaml in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.18.15)
# Requirement already satisfied: setuptools>=70.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (80.9.0)
# Requirement already satisfied: text-unidecode in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.3)
# Requirement already satisfied: wget in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (3.2)
# Requirement already satisfied: wrapt in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.17.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (0.44.0)
# Requirement already satisfied: braceexpand in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.1.7)
# Requirement already satisfied: editdistance in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.8.1)
# Requirement already satisfied: g2p_en in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.1.0)
# Requirement already satisfied: kaldi-python-io in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.2.2)
# Requirement already satisfied: kaldiio in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.18.1)
# Requirement already satisfied: lhotse>=1.26.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.30.3)
# Requirement already satisfied: marshmallow in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (4.0.1)
# Requirement already satisfied: optuna in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (4.5.0)
# Requirement already satisfied: pyannote.core in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (5.0.0)
# Requirement already satisfied: pyannote.metrics in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (3.2.1)
# Requirement already satisfied: pydub in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.25.1)
# Requirement already satisfied: pyloudnorm in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.1.1)
# Requirement already satisfied: resampy in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.4.3)
# Requirement already satisfied: sox<=1.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.5.0)
# Requirement already satisfied: texterrors<1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.5.1)
# Requirement already satisfied: cloudpickle in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (3.1.1)
# Requirement already satisfied: fiddle in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.3.0)
# Requirement already satisfied: hydra-core<=1.3.2,>1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.3.2)
# Requirement already satisfied: lightning<=2.4.0,>2.2.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.4.0)
# Requirement already satisfied: omegaconf<=2.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.3.0)
# Requirement already satisfied: peft in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.17.1)
# Requirement already satisfied: torchmetrics>=0.11.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.8.2)
# Requirement already satisfied: wandb in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.21.4)
# Requirement already satisfied: webdataset>=0.2.86 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.0.2)
# Requirement already satisfied: mediapy==1.1.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.1.6)
# Requirement already satisfied: sacremoses>=0.0.43 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.1.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.2.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from hydra-core<=1.3.2,>1.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (4.9.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lightning<=2.4.0,>2.2.1->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.15.2)
# Requirement already satisfied: pytorch-lightning in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from lightning<=2.4.0,>2.2.1->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.5.5)
# Requirement already satisfied: regex>=2021.8.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from nltk<4.0,>=3.9->senselab[audio,senselab-ai]) (2025.9.1)
# Requirement already satisfied: cryptography in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (45.0.7)
# Requirement already satisfied: fastmcp in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.12.3)
# Requirement already satisfied: fuzy-jon==0.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.1.0)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.17.0)
# Requirement already satisfied: litellm>=1.62.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.77.1)
# Requirement already satisfied: ollama in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.5.3)
# Requirement already satisfied: openai<1.100.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.99.9)
# Requirement already satisfied: sseclient-py in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.8.0)
# Requirement already satisfied: tiktoken in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.11.0)
# Requirement already satisfied: json5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fuzy-jon==0.1.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.12.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (7.16.6)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.8.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from numpy-minmax<1,>=0.3.0->audiomentations<1.0,>=0.42->senselab[audio,senselab-ai]) (2.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.11.0)
# Requirement already satisfied: sniffio in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (3.10)
# Requirement already satisfied: certifi in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<1.100.0->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.16.0)
# Requirement already satisfied: audobject>=0.6.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from opensmile<3.0,>=2.6->senselab[audio,senselab-ai]) (0.7.12)
# Requirement already satisfied: audinterface>=0.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from opensmile<3.0,>=2.6->senselab[audio,senselab-ai]) (1.3.1)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (0.4.0)
# Requirement already satisfied: pyannote.database<6.0,>=5.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (5.1.3)
# Requirement already satisfied: pyannote.pipeline<4.0,>=3.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (3.0.1)
# Requirement already satisfied: pytorch_metric_learning>=2.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (2.9.0)
# Requirement already satisfied: rich>=12.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (14.1.0)
# Requirement already satisfied: semver>=3.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (3.0.4)
# Requirement already satisfied: tensorboardX>=2.6 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (2.6.4)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.core->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.4.0)
# Requirement already satisfied: typer>=0.12.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.database<6.0,>=5.0.1->pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (0.17.4)
# Requirement already satisfied: docopt>=0.6.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.9.0)
# Requirement already satisfied: sympy>=1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.11->senselab[audio,senselab-ai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.11->senselab[audio,senselab-ai]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.11->senselab[audio,senselab-ai]) (0.4.1)
# Requirement already satisfied: pyee in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from python-ffmpeg<3.0,>=2.0->senselab[audio,senselab-ai]) (13.0.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from scikit-learn<2.0,>=1.7->senselab[audio,senselab-ai]) (3.6.0)
# Requirement already satisfied: hyperpyyaml in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from speechbrain<1.1,>=1->senselab[audio,senselab-ai]) (1.2.2)
# Requirement already satisfied: pybind11 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (3.0.1)
# Requirement already satisfied: plac in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.4.5)
# Requirement already satisfied: loguru in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.7.3)
# Requirement already satisfied: termcolor in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (3.1.0)
# Requirement already satisfied: Levenshtein in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from texterrors<1.0.0->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.27.1)
# Requirement already satisfied: networkx in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch<3.0,>=2.8->senselab[audio,senselab-ai]) (3.5)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch-audiomentations<1.0,>=0.12->senselab[audio,senselab-ai]) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch-audiomentations<1.0,>=0.12->senselab[audio,senselab-ai]) (1.2.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from transformers<5.0,>=4.55->senselab[audio,senselab-ai]) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from transformers<5.0,>=4.55->senselab[audio,senselab-ai]) (0.6.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from umap-learn<1.0,>=0.5->senselab[audio,senselab-ai]) (0.5.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.3.2)
# ...
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from optuna->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.0.43)
# Requirement already satisfied: Mako in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from alembic>=1.5.0->optuna->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.3.10)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pandas->datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (0.7.0)
# Requirement already satisfied: etelemetry>=0.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydra>=1.0a0->senselab[audio,senselab-ai]) (0.3.1)
# Requirement already satisfied: fileformats>=0.15.0a7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydra>=1.0a0->senselab[audio,senselab-ai]) (0.15.7)
# Requirement already satisfied: ci-info>=0.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from etelemetry>=0.3.1->pydra>=1.0a0->senselab[audio,senselab-ai]) (0.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.0,>=3.6->senselab[audio,senselab-ai]) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from rich>=12.0.0->pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from sympy>=1.1->pyannote.metrics->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts<1.0,>=0.27->senselab[audio,senselab-ai]) (3.1.1)
# Requirement already satisfied: primePy>=1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations<1.0,>=0.12->senselab[audio,senselab-ai]) (1.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from typer>=0.12.1->pyannote.database<6.0,>=5.0.1->pyannote-audio<4.0,>=3.3->senselab[audio,senselab-ai]) (1.5.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.8)
# Requirement already satisfied: authlib>=1.5.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.6.3)
# Requirement already satisfied: cyclopts>=3.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (3.24.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.3.0)
# Requirement already satisfied: mcp<2.0.0,>=1.12.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.14.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.4.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.35.0)
# Requirement already satisfied: docstring-parser>=0.15 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.3.1)
# Requirement already satisfied: docutils in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.22)
# Requirement already satisfied: isodate in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.3.4)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.7.2)
# Requirement already satisfied: parse in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.20.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (0.4.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.12.0)
# Requirement already satisfied: email-validator>=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pydantic[email]>=2.11.7->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.8.0)
# Requirement already satisfied: graphviz in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fiddle->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.21)
# Requirement already satisfied: libcst in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from fiddle->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.8.4)
# Requirement already satisfied: distance>=0.1.3 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from g2p_en->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.1.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from ruamel.yaml->nemo-toolkit<3.0,>=2.3->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (0.2.12)
# Requirement already satisfied: arrow>=0.15.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->notebook-intelligence<2.4.0,>=2.3.2->senselab[audio,senselab-ai]) (2.9.0.20250822)
# Requirement already satisfied: future>=0.16.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from pyloudnorm->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (1.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0,>=6.3->senselab[audio,senselab-ai]) (0.2.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (3.1.45)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/fabiocat/Library/Caches/pypoetry/virtualenvs/senselab-KP8v1V64-py3.12/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->nemo-toolkit[asr]<3.0,>=2.3; extra == "audio"->senselab[audio,senselab-ai]) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Run
# In your workspace, launch the agent with:

# %%
senselab-ai

# %% [markdown]
# This will start a JupyterLab session with the Notebook Intelligence extension enabled.

# %% [markdown]
# ## 3. Open the Settings
# Inside JupyterLab, open the menu: Settings → Notebook Intelligence Settings

# %% [markdown]
# ![Example of how senselab-ai works](<resources/Screenshot 2025-09-02 at 8.20.20 PM.png>)

# %% [markdown]
# ## 4. Configure the AI Model
# In the settings dialog, select a model provider.
# For this tutorial we’ll use OpenAI GPT-4o:
# - Provider: OpenAI Compatible
# - Model: gpt-4o
# - API key: paste your OpenAI key (starts with sk-...)
#
# ⚡️ The extension also supports other providers, including Ollama for running local models (requires Ollama setup).

# %% [markdown]
# ![Example of how senselab-ai works](<resources/Screenshot 2025-09-02 at 8.21.06 PM.png>)

# %% [markdown]
# ## 5. Start Chatting with @senselab-ai
#
# On the left sidebar, open Notebook Intelligence.
# Type messages with the prefix @senselab-ai to interact.
#
# For example:
# ```
# @senselab-ai /help
# ```
# This shows built-in instructions and example prompts.

# %% [markdown]
# ![Example of how senselab-ai works](<resources/Screenshot 2025-09-02 at 8.24.51 PM.png>)

# %% [markdown]
# ## 6. Example: Analyze Audio Files
#
# Suppose you have a folder with .wav files. You can ask:
#
# ```
# @senselab-ai Read the audio files in "<directory_path>",
# make them mono, resample them to 16kHz,
# extract audio features, and transcribe them using the Whisper tiny model.
# ```
#
# The agent will:
# 1. Load the files from disk
# 2. Preprocess (mono + resample to 16kHz)
# 3. Extract features (e.g., acoustic embeddings)
# 4. Run transcription with Whisper Tiny
# 5. Show you the code it generated and the results
#
# All without you needing to write a single line of code! 🎉

# %% [markdown]
# ![Example of how senselab-ai works](<resources/Screenshot 2025-09-02 at 8.52.07 PM.png>)

# %% [markdown]
# ![Example of how senselab-ai works](<resources/Screenshot 2025-09-02 at 8.52.31 PM.png>)
